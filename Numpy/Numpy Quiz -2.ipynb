# %%
import numpy as np

# %% [markdown]
# Create a 2D numpy array from baseball. Name it np_baseball.

# %%
baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

# %% [markdown]
# Print out the shape attribute of np_baseball

# %%
np.shape(baseball)
# Out:
# (4, 2)

# %% [markdown]
# Print out the third row of np_baseball.

# %%
baseball[2]
# Out:
# [210, 98.5]

# %% [markdown]
# Create numpy array np_height_in that is equal to first column of np_baseball.

# %%
new_arr=baseball[0]
new_arr
# Out:
# [180, 78.4]

# %% [markdown]
# Print out the mean of np_height_in.

# %%
np.mean(new_arr)
# Out:
# np.float64(129.2)

# %% [markdown]
# Print out the median of np_height_in.

# %%
np.median(new_arr)
# Out:
# np.float64(129.2)

# %% [markdown]
# Print out the standard deviation of np_height_in.

# %%
np.std(new_arr)
# Out:
# np.float64(50.8)

# %% [markdown]
# Convert heights and positions, which are regular lists, to numpy arrays. Call them np_heights and np_positions.

# %%
heights=[191, 184, 185, 180, 181, 187, 170, 179, 183, 186, 185, 170, 187, 183, 173, 188, 183, 180, 188]
positions=['GK', 'M', 'A', 'D', 'M', 'D', 'M', 'M', 'M', 'A', 'M', 'M', 'A', 'A', 'A', 'M', 'D', 'A', 'D']

# %%
np_heights=np.array(heights)
np_positions=np.array(positions)

np_positions
# Out:
# array(['GK', 'M', 'A', 'D', 'M', 'D', 'M', 'M', 'M', 'A', 'M', 'M', 'A',
#        'A', 'A', 'M', 'D', 'A', 'D'], dtype='<U2')

# %% [markdown]
# Extract all the heights of the goalkeepers. Assign the result to gk_heights.

# %%
'''mask=np_positions=='GK'

print(mask)
'''

gk_heights=np_heights[np_positions=='GK']
gk_heights
# Out:
# array([191])

# %% [markdown]
# Extract all the heights of all the other players. Assign the result to other_heights

# %%
gz_heights=np_heights[np_positions!='GK']
gz_heights
# Out:
# array([184, 185, 180, 181, 187, 170, 179, 183, 186, 185, 170, 187, 183,
#        173, 188, 183, 180, 188])

# %% [markdown]
# Print out the median height of the goalkeepers

# %%
np.median(gk_heights)
# Out:
# np.float64(191.0)

# %% [markdown]
# Do the same for the other players. Print out their median height.

# %%
np.median(gz_heights)
# Out:
# np.float64(183.0)
